# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("WHO-COVID-19-global-data.csv")

# %%
data.head(300)
# Out:
#     Date_reported Country_code      Country WHO_region  New_cases  \
# 0      2020-01-03           AF  Afghanistan       EMRO          0
# 1      2020-01-04           AF  Afghanistan       EMRO          0
# 2      2020-01-05           AF  Afghanistan       EMRO          0
# 3      2020-01-06           AF  Afghanistan       EMRO          0
# 4      2020-01-07           AF  Afghanistan       EMRO          0
# ..            ...          ...          ...        ...        ...
# 295    2020-10-24           AF  Afghanistan       EMRO         61
# 296    2020-10-25           AF  Afghanistan       EMRO         81
# 297    2020-10-26           AF  Afghanistan       EMRO         65
# 298    2020-10-27           AF  Afghanistan       EMRO        104
# 299    2020-10-28           AF  Afghanistan       EMRO         95
#
#      Cumulative_cases  New_deaths  Cumulative_deaths
# 0                   0           0                  0
# 1                   0           0                  0
# ...

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
data.tail()
# Out:
#       Date_reported Country_code   Country WHO_region  New_cases  \
# 89344    2021-01-09           ZW  Zimbabwe       AFRO        985
# 89345    2021-01-10           ZW  Zimbabwe       AFRO        839
# 89346    2021-01-11           ZW  Zimbabwe       AFRO        978
# 89347    2021-01-12           ZW  Zimbabwe       AFRO        820
# 89348    2021-01-13           ZW  Zimbabwe       AFRO        942
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 89344             19660          22                468
# 89345             20499          15                483
# 89346             21477          24                507
# 89347             22297          21                528
# 89348             23239          23                551

# %%
data.describe()
# Out:
#            New_cases  Cumulative_cases    New_deaths  Cumulative_deaths
# count   89349.000000      8.934900e+04  89349.000000       89349.000000
# mean     1011.035468      9.637904e+04     21.873060        2744.111854
# std      7100.143095      6.666171e+05    125.537932       15441.390993
# min    -32952.000000      0.000000e+00   -514.000000           0.000000
# 25%         0.000000      3.000000e+00      0.000000           0.000000
# 50%         2.000000      6.680000e+02      0.000000          11.000000
# 75%       140.000000      1.327300e+04      2.000000         246.000000
# max    402270.000000      2.242859e+07   6409.000000      373329.000000

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %% [markdown]
# # Relating the variable with scattter Plot

# %%
sns.relplot( x="New_deaths", y ="New_cases", data = data)

# %%
sns.pairplot(data)

# %%
sns.relplot( x="New_cases", y ="New_deaths", hue = "WHO_region",data = data,height=4, aspect =2)

# %%
sns.relplot( x="New_cases", y ="New_deaths",kind ="line" ,data = data, height=4, aspect =2)

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
sns.catplot( x="New_cases", y ="New_deaths" ,data = data, height=4, aspect =2)

# %%
data.plot(figsize=(10,5),legend = True)
